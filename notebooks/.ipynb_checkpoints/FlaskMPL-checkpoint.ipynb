# %%
#!pip install -i https://test.pypi.org/simple/ brown-edu-dmtools==0.1.10

# %%
import matplotlib.pyplot as plt
import numpy as np
import ast
## plt.rcParams['text.usetex'] = True

# for legend
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# %%
from brown_edu_dmtools.dmtools_client_package.dmtools_client_module import DMToolsClient
from brown_edu_dmtools.dmtools_client_package.dmtools_client_module import DMToolTestData
from brown_edu_dmtools.dmtools_client_package.dmtools_client_module import PlotTrace

# %%
## get api key and user id from local .env file
from dotenv import load_dotenv
import os
from os import environ, path
#BASE_DIR = path.abspath(path.dirname(__file__))
BASE_DIR = os.getcwd()
#load_dotenv(path.join(BASE_DIR, ".env"))
load_dotenv(path.join(BASE_DIR, ".env"), override=True)
MY_DMTOOLS_APIKEY = environ.get("MY_DMTOOLS_APIKEY")
MY_DMTOOLS_USERID = environ.get("MY_DMTOOLS_USERID")
Client = DMToolsClient(MY_DMTOOLS_USERID, MY_DMTOOLS_APIKEY)
#Client.request_header

# %%
pt = PlotTrace()

# %%
import json
# Define the query parameters as a dictionary
params = {
    'name_ne' : "CDMS",
    'id_ne' = 1
}

params_as_string = json.dumps(params)

# Pass the encoded query to the API client
r = Client.query(subject='plot', query_criteria=params_as_string)
r
# Out:
# query function encoded query string >>>  name_like%3DCDMS
# query_url >>>>>>>>>>> https://dmtools.brown.edu/dmtool/fastapi_data/open/data/0.0/plot/query/?query_in=name_like%3DCDMS
# [{'id': 8,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 22,
#   'y_max': -42,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS2009',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 50,
#   'created_at': '2009-08-27T07:09:21',
#   'open': None,
#   'x_max': 100,
#   'updated_at': '2009-09-01T00:15:57',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 29,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 69,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS_nov2009',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2009-11-22T20:34:08',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2009-11-22T20:36:36',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 52,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 105,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS Test',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-01-04T15:02:06',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2010-02-16T03:22:26',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 54,
#   'y_min': -50,
#   'plot_png': None,
#   'old_id': 107,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS_new_results',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-01-04T18:59:18',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2011-11-10T16:31:54',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 73,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 147,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSTest',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-02-03T15:41:46',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2011-03-16T19:18:53',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 94,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 177,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-02-25T23:39:39',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2010-02-25T23:40:55',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 97,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 183,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS II limits',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-02-28T00:18:42',
#   'open': 1,
#   'x_max': 500,
#   'updated_at': '2010-02-28T00:22:42',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 104,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 191,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-03-09T20:48:19',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2010-03-09T20:48:19',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 113,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 216,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms SI',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-03-24T19:14:08',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2010-03-24T19:15:13',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 131,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 241,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS1',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2010-04-13T11:01:46',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2010-04-13T14:50:42',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 138,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 250,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'ZEPLIN-III, XENON10, CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-04-20T12:02:31',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2010-04-20T12:23:00',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 156,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 269,
#   'y_max': -42,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'LUX-XENON100-SuperCDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-05-03T20:38:32',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2012-07-10T14:59:41',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 159,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 272,
#   'y_max': -42,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'SuperCDMS-XENON100-LUX',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-05-04T17:33:15',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2010-05-05T00:01:41',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 169,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 285,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2010-05-13T09:30:33',
#   'open': None,
#   'x_max': 50,
#   'updated_at': '2010-05-13T09:33:25',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 185,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 301,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSII+XENON10 SI',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-05-29T17:59:47',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2010-05-29T18:39:19',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 195,
#   'y_min': -50,
#   'plot_png': None,
#   'old_id': 313,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS II Limit',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2010-06-10T21:48:27',
#   'open': 1,
#   'x_max': 500,
#   'updated_at': '2010-06-10T21:49:53',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 232,
#   'y_min': -42,
#   'plot_png': None,
#   'old_id': 367,
#   'y_max': -32,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS II (Soudan) SI & SD limits, Ge, Dec. 2010',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2011-02-23T03:41:06',
#   'open': 1,
#   'x_max': 10,
#   'updated_at': '2011-10-11T05:34:40',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 238,
#   'y_min': -42,
#   'plot_png': None,
#   'old_id': 374,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS I (SUF) limits, Ge+Si and Si only',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-02-24T01:04:24',
#   'open': 1,
#   'x_max': 100,
#   'updated_at': '2011-02-24T01:07:44',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 241,
#   'y_min': -40,
#   'plot_png': None,
#   'old_id': 377,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS I (SUF) Si+Ge and Si only, 1 to 5 GeV (2010).  These data sets need work - too few points',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-02-24T02:50:35',
#   'open': 1,
#   'x_max': 5,
#   'updated_at': '2011-02-24T03:03:34',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 262,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 414,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSII Soudan',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2011-03-09T12:44:31',
#   'open': None,
#   'x_max': 5000,
#   'updated_at': '2011-03-09T18:38:17',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 287,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 453,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSXenon',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-03-29T20:51:17',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2011-03-29T21:18:31',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 288,
#   'y_min': -48,
#   'plot_png': None,
#   'old_id': 454,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'FutureCDMSXenon',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-03-29T21:19:04',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-03-29T21:41:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 306,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 487,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'DAMA, CDMS-II for Cafe com Fisica',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 5,
#   'created_at': '2011-04-10T23:44:38',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-04-11T00:10:26',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 323,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 520,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS+CogeNT+XENON100',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2011-04-21T13:46:21',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2011-05-25T13:52:45',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 327,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 524,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS Princeton',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2011-04-24T03:35:28',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-07-25T13:39:54',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 354,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 563,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2011-05-19T17:38:09',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2011-05-19T17:41:44',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 357,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 566,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSI&II',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2011-05-23T14:19:49',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2011-05-26T18:51:33',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 361,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 570,
#   'y_max': -42,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'PTDC (XE10, ZIII, CDMS-II, Edelweiss, XE100)',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-05-24T16:33:57',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-05-24T16:47:53',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 363,
#   'y_min': -50,
#   'plot_png': None,
#   'old_id': 572,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSII',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-05-25T15:38:58',
#   'open': None,
#   'x_max': 5000,
#   'updated_at': '2011-05-25T16:48:38',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 430,
#   'y_min': -41,
#   'plot_png': None,
#   'old_id': 684,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS low m',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-08-11T10:56:06',
#   'open': None,
#   'x_max': 50,
#   'updated_at': '2011-08-11T11:07:13',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 444,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 709,
#   'y_max': -41,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS-EDELWEISS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-08-31T21:47:34',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2012-02-28T18:20:42',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 451,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 723,
#   'y_max': -41,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'Edelweiss - CDMS combined',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-09-13T22:50:47',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2012-02-23T12:30:07',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 452,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 724,
#   'y_max': -41,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS-Edelweiss Combined',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2011-09-13T23:13:51',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2011-09-13T23:14:24',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 490,
#   'y_min': -41,
#   'plot_png': None,
#   'old_id': 776,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS Low Energy Analysis, PRL April 2011',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2011-10-11T04:59:25',
#   'open': 1,
#   'x_max': 10,
#   'updated_at': '2011-10-11T18:01:06',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 491,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 777,
#   'y_max': -41,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS II Mar 2010',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 10,
#   'created_at': '2011-10-11T06:25:46',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-10-11T17:37:45',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 514,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 813,
#   'y_max': -33,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdmsedelweiss',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 5,
#   'created_at': '2011-10-22T15:56:00',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2011-10-22T16:07:21',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 515,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 814,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS low thresh and cog',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-10-22T16:04:30',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2011-10-22T16:04:30',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 520,
#   'y_min': -48,
#   'plot_png': None,
#   'old_id': 820,
#   'y_max': -35,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'le_cdms',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2011-10-25T13:17:23',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2011-10-25T13:20:23',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 536,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 851,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-11-16T14:16:44',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2011-11-16T14:18:22',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 570,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 916,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2011-12-07T17:59:27',
#   'open': None,
#   'x_max': 10,
#   'updated_at': '2011-12-07T18:02:22',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 628,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 998,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'SuperCDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-02-01T19:52:40',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-02-01T19:53:23',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 629,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 999,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS SD',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-02-01T19:54:38',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-02-01T19:56:00',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 718,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1134,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-04-07T21:52:09',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-04-07T21:52:09',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 739,
#   'y_min': -42,
#   'plot_png': None,
#   'old_id': 1165,
#   'y_max': -37,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS1&2',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-04-19T00:50:37',
#   'open': None,
#   'x_max': 50,
#   'updated_at': '2012-04-19T05:22:01',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 779,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 1224,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-05-16T06:21:37',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2012-06-07T09:10:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 814,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 1286,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'scdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-06-12T23:50:41',
#   'open': None,
#   'x_max': 500,
#   'updated_at': '2012-06-12T23:51:10',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 843,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1338,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-07-02T03:43:13',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-07-02T03:43:41',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 901,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1429,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-07-26T18:48:16',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-07-26T18:52:09',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 943,
#   'y_min': -36,
#   'plot_png': None,
#   'old_id': 1500,
#   'y_max': -44,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2012-09-11T12:05:00',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2012-09-11T12:14:03',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 967,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1545,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdmss',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-09-25T15:58:27',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2012-09-25T15:58:27',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 968,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 1551,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'MW_CDMS',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2012-09-29T17:21:52',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2012-09-29T18:05:11',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 969,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 1552,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'MW_CDMS_Edel',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2012-09-29T18:05:49',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2012-10-13T15:11:51',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1014,
#   'y_min': -50,
#   'plot_png': None,
#   'old_id': 1623,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms_edelweis_si_nuc',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2012-11-08T11:05:10',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2012-11-08T11:13:22',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1075,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1719,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'test CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-02-11T16:03:18',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-02-11T16:06:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1156,
#   'y_min': -48,
#   'plot_png': None,
#   'old_id': 1858,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'dama cogent3 cresst cdms+edelweiss xenon100',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 5,
#   'created_at': '2013-04-25T03:59:34',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2013-04-25T04:04:26',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1157,
#   'y_min': -48,
#   'plot_png': None,
#   'old_id': 1859,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'dama cogent3 cresst cdms+edelweiss xenon100 cdms-low',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 5,
#   'created_at': '2013-04-25T04:06:10',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2013-04-25T04:09:32',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1159,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 1861,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS stuff?',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-04-26T11:43:15',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-04-26T11:44:58',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1257,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2039,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-08-07T04:29:39',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-08-07T04:30:44',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1265,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2047,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS Si',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-08-13T22:07:09',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-08-13T22:07:09',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1329,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 2139,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 5,
#   'created_at': '2013-09-08T00:22:46',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2013-09-08T00:34:09',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1338,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 2158,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS Ge',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-09-11T14:56:38',
#   'open': None,
#   'x_max': 100,
#   'updated_at': '2013-09-11T14:59:24',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1342,
#   'y_min': -50,
#   'plot_png': None,
#   'old_id': 2165,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS-Limits vs KK',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 10,
#   'created_at': '2013-09-12T09:32:21',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2013-09-12T09:44:24',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1351,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2175,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSlite',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-09-16T13:21:40',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-09-16T13:21:40',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1356,
#   'y_min': -47,
#   'plot_png': None,
#   'old_id': 2180,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'deapcdmsxenon',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 10,
#   'created_at': '2013-09-18T16:56:48',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2013-09-18T17:10:21',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1365,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2189,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'SuperCDMS SNOLAB Projected Limits, September 21, 2013',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-09-21T08:07:14',
#   'open': 1,
#   'x_max': 1000,
#   'updated_at': '2013-09-21T08:33:07',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1367,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2191,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms_xenon',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-09-22T08:59:38',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-09-22T08:59:38',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1391,
#   'y_min': -40,
#   'plot_png': None,
#   'old_id': 2221,
#   'y_max': -32,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS SD',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-10-03T01:44:04',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-10-03T02:48:31',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1425,
#   'y_min': -49,
#   'plot_png': None,
#   'old_id': 2265,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2013-10-20T17:19:06',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2013-10-21T00:53:28',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1430,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2273,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-10-22T21:26:55',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-10-22T21:26:55',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1461,
#   'y_min': -44,
#   'plot_png': None,
#   'old_id': 2318,
#   'y_max': -37,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-11-05T05:37:55',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-11-05T05:44:46',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1469,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 2327,
#   'y_max': -30,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-11-06T12:42:33',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2013-11-06T12:46:01',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1497,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 2364,
#   'y_max': -38,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2013-11-22T12:36:20',
#   'open': None,
#   'x_max': 100,
#   'updated_at': '2013-11-22T12:38:16',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1509,
#   'y_min': -45,
#   'plot_png': None,
#   'old_id': 2378,
#   'y_max': -40,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'SCDMS Soudan',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 5,
#   'created_at': '2013-11-26T17:09:59',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2013-11-27T08:35:19',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1551,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2439,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSlite Soudan, Run 1 (2013)',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2014-01-09T20:57:54',
#   'open': 1,
#   'x_max': 100,
#   'updated_at': '2014-01-09T21:03:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1552,
#   'y_min': -42,
#   'plot_png': None,
#   'old_id': 2440,
#   'y_max': -35,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSlite',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2014-01-09T21:14:17',
#   'open': None,
#   'x_max': 15,
#   'updated_at': '2014-01-09T21:17:05',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1570,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2465,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdmslite',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-01-29T10:26:54',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2014-01-29T10:27:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1640,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2568,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-03-13T09:37:13',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2014-03-13T09:37:13',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1643,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2572,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'SuperCDMS LT exclusion, 90% C.L.',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-03-14T16:52:33',
#   'open': 1,
#   'x_max': 10000,
#   'updated_at': '2014-03-14T16:53:20',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1680,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2640,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS-Si',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-04-02T22:59:48',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2014-04-02T23:00:23',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1703,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2666,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'super cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-04-14T02:45:08',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2014-04-14T02:45:50',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1744,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2731,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2014-05-12T03:38:29',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2014-05-13T08:43:03',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1752,
#   'y_min': -46,
#   'plot_png': None,
#   'old_id': 2740,
#   'y_max': -36,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'superCDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2014-05-13T21:20:09',
#   'open': None,
#   'x_max': 1000,
#   'updated_at': '2014-05-13T21:21:53',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1900,
#   'y_min': -10,
#   'plot_png': None,
#   'old_id': 2964,
#   'y_max': -1,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'pb',
#   'legend_eps': None,
#   'name': 'superCDMS',
#   'user_id': None,
#   'no_id': 1,
#   'x_min': 1,
#   'created_at': '2015-03-03T12:58:26',
#   'open': None,
#   'x_max': 100,
#   'updated_at': '2015-03-03T13:02:02',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 1901,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 2965,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2015-03-03T19:39:44',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2015-03-03T19:45:16',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 2011,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 3122,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2015-07-10T20:02:31',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2015-07-10T20:03:34',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 2071,
#   'y_min': -42,
#   'plot_png': None,
#   'old_id': 3208,
#   'y_max': -39,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CresstSCDMS2015',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 3,
#   'created_at': '2015-09-16T07:34:17',
#   'open': 1,
#   'x_max': 30,
#   'updated_at': '2015-09-16T07:36:24',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 2386,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 3637,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'CDMSlite',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2016-12-21T12:51:38',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2016-12-23T13:07:52',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 2532,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 3828,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'dama cdms',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2017-06-07T15:28:02',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2017-06-07T15:31:58',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'},
#  {'id': 2958,
#   'y_min': -54,
#   'plot_png': None,
#   'old_id': 4455,
#   'y_max': -26,
#   'legend_png': None,
#   'old_name': None,
#   'x_units': 'GeV/c^2',
#   'plot_eps': None,
#   'old_user_id': None,
#   'y_units': 'cm2',
#   'legend_eps': None,
#   'name': 'superCDMS',
#   'user_id': None,
#   'no_id': 0,
#   'x_min': 1,
#   'created_at': '2020-01-16T12:41:46',
#   'open': None,
#   'x_max': 10000,
#   'updated_at': '2020-01-16T14:04:34',
#   'subject': 'plot',
#   'archived_at': '1980-01-01T00:00:00'}]

# %%
plot_id = 489
datasets = Client.read_by_plot_id(subject='data_display',id=plot_id)
datasets
# Out:
# [{'id': 1066,
#   'subject': 'data_display',
#   'name': None,
#   'old_id': None,
#   'old_plot_id': 775,
#   'limit_id': 406,
#   'plot_id': 489,
#   'color': 'k',
#   'style': 'line',
#   'data_id': 349,
#   'updated_at': '2011-10-07T17:35:05',
#   'open': None}]

# %%
pt = PlotTrace()
#pt.set_values(trace_color, trace_style)
print(pt.mode,pt.line,pt.marker,pt.fillcolor,pt.opacity,pt.fill)
# Out:
# lines {'color': 'red', 'width': 1, 'dash': 'solid'} {'symbol': 'x'} rgba(0,255,255,0.05) 1 toself

# %%
'''
try:
    y_rescale = float(a_data_json_obj['y_rescale'])
except:
    y_rescale = 1
try:
    x_rescale = float(a_data_json_obj['x_rescale'])
except:
    x_rescale = 1

## when do we rescale?
data_data_resp_df['cross_sections'] = data_data_resp_df['y'].astype(float).apply(lambda y: y * y_rescale)
data_data_resp_df['masses'] = data_data_resp_df['x'].astype(float).apply(lambda x: x * x_rescale)
'''

# %%
def get_mpl_plot(plot_id_in, width_in=600, height_in=600):
    datasets = Client.read_by_plot_id(subject='data_display',id=plot_id_in)
    px = 1/plt.rcParams['figure.dpi']  # pixel in inches
    plt.figure(figsize=(width_in*px, height_in*px))
    for d in datasets:
        data_id = d['data_id']
        trace_data = Client.read(id=data_id)
        y_rescale = float(trace_data[0]['y_rescale'])
        x_rescale = float(trace_data[0]['x_rescale'])
        trace_name = trace_data[0]['data_label']
        string_data = trace_data[0]['data']
        style = d['style']
        color = d['color']
        pt.set_values(color, style)
        list_data = ast.literal_eval(string_data)
        trace_count = len(list_data)
        trace_names_int = list(range(0,trace_count))
        trace_names_int
        trace_names = []
        for t in trace_names_int:
            trace_names.append(str(t))
            x = [item[0] for item in list_data[t]]
            y = [item[1] for item in list_data[t]]
            cross_sections =  [float(yi) * y_rescale for yi in y]
            masses =  [float(xi) * x_rescale for xi in x]
            
            if pt.fill != 'toself':
                plt.plot(masses, cross_sections, label=trace_name)
            else:
                plt.fill_between(masses, cross_sections, alpha=0.3, label=trace_name)
    
    # Add labels and title
    # plt.xlabel('Masses')
    # plt.ylabel('Cross Sections')
    
    
    #plt.title('Two Lists of Lists Plotted')
    plt.xscale('log')
    plt.yscale('log')

    return plt

my_plot = Client.get_mpl_plot(plot_id)
my_plot = get_mpl_plot(plot_id)

my_plot.show()

# %%
my_plot = Client.get_mpl_plot(489)
my_plot.show()

# %%
def get_mpl_legend(plot_id_in, width_in=600, height_in=200):
    datasets = Client.read_by_plot_id(subject='data_display',id=plot_id_in)
    px = 1/plt.rcParams['figure.dpi']  # pixel in inches
    plt.figure(figsize=(width_in*px, height_in*px))
    handles = []
    
    for d in datasets:
        data_id = d['data_id']
        trace_data = Client.read(id=data_id)
        trace_name = trace_data[0]['data_label']
        string_data = trace_data[0]['data']
        style = d['style']
        color = d['color']
        pt.set_values(color, style)
        list_data = ast.literal_eval(string_data)
        trace_count = len(list_data)
        trace_names_int = list(range(0,trace_count))
        trace_names_int
        trace_names = []
        for t in trace_names_int:
            trace_names.append(str(t))
            x = [item[0] for item in list_data[t]]
            y = [item[1] for item in list_data[t]]
            
            if pt.fill != 'toself':
                append_this = mlines.Line2D([], [], color=color, label=trace_name, linestyle='-')
            else:
                append_this = mpatches.Patch(color=color, alpha=0.3, hatch='/', label=trace_name)
            handles.append(append_this)
    
    #line1_handle = mlines.Line2D([], [], color='blue', label='Sine Wave', linestyle='-')
    #line2_handle = mlines.Line2D([], [], color='green', label='Cosine Wave', linestyle='-')
    
    #fill1_handle = mpatches.Patch(color='blue', alpha=0.3, hatch='/', label='Sine Fill')
    #fill2_handle = mpatches.Patch(color='green', alpha=0.3, hatch='\\', label='Cosine Fill')
    
    # Combine handles and labels
    #handles = [line1_handle, line2_handle, fill1_handle, fill2_handle]
    labels = [handle.get_label() for handle in handles]
    
    # Create a new figure just for the legend
    fig, ax = plt.subplots(figsize=(2, 2))
    ax.legend(handles=handles, labels=labels, loc='center')
    ax.axis('off')  # Hide the axes
    return plt

my_legend = Client.get_mpl_legend(plot_id)

my_legend.show()

# %%
# Now you can plot these two lists using matplotlib

for tl in range(0,trace_count):
    # Plot the first list as a line
    #list_data[tl]
    '''
    numpy_array = np.array(list_data[tl])
    x = numpy_array[:, 0]
    y = numpy_array[:, 1]
    '''
    x = [item[0] for item in list_data[tl]]
    y = [item[1] for item in list_data[tl]]
    
    if pt.fill != 'toself':
        plt.plot(x, y, label=str(tl))
    else:
        plt.fill_between(x, y, alpha=0.3, label='Area Trace')


# Add labels and title
plt.xlabel('Masses')
plt.ylabel('Cross Sections')


#plt.title('Two Lists of Lists Plotted')
plt.xscale('log')
plt.yscale('log')

# Show legend
#plt.legend()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Now you can plot these two lists using matplotlib
# ----> 3 for tl in range(0,trace_count):
#       4     # Plot the first list as a line
#       5     #list_data[tl]
#       6     '''
#       7     numpy_array = np.array(list_data[tl])
#       8     x = numpy_array[:, 0]
#       9     y = numpy_array[:, 1]
#      10     '''
#      11     x = [item[0] for item in list_data[tl]]
#
# NameError: name 'trace_count' is not defined

# %%
'''

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the plot
plt.plot(x, y)

# Add a title and labels using mathtext
plt.title(r'This is a $\sin(x)$ function', fontsize=16)  # LaTeX-like syntax
plt.xlabel(r'$\theta$ (radians)', fontsize=14)           # LaTeX-like syntax
plt.ylabel(r'$\sin(\theta)$', fontsize=14)               # LaTeX-like syntax

# Display the plot
plt.show()
'''

# %%
# Example data structure: list of list of lists
# Assuming the structure: [[[x_values_line], [y_values_line]], [[x_values_area], [y1_values_area], [y2_values_area]]]
traces = [
    [[1, 2, 3], [2, 3, 4]],        # Line trace
    [[1, 2, 3], [4, 5, 6], [1, 1, 1]],  # Area trace (with y2 values)
    [[1, 2, 3], [6, 7, 8]]         # Line trace
]

# Create a plot
plt.figure(figsize=(10, 6))

# Iterate over traces and plot accordingly
for trace in traces:
    x_values = trace[0]
    y_values = trace[1]
    
    if len(trace) == 2:  # Line trace
        plt.plot(x_values, y_values, label='Line Trace')
    elif len(trace) == 3:  # Area trace
        y2_values = trace[2]
        plt.fill_between(x_values, y_values, y2_values, alpha=0.3, label='Area Trace')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Traces: Lines and Areas')

# Show legend
plt.legend()

# Show plot
plt.show()
