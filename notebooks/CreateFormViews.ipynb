# %%
from brown_edu_dmtools.dmtools_client_package.dmtools_client_module import DMToolsClient

# %%
## get api key and user id from local .env file
from dotenv import load_dotenv
import os
from os import environ, path
#BASE_DIR = path.abspath(path.dirname(__file__))
BASE_DIR = os.getcwd()
load_dotenv(path.join(BASE_DIR, ".env"))
MY_DMTOOLS_APIKEY = environ.get("MY_DMTOOLS_APIKEY")
MY_DMTOOLS_USERID = environ.get("MY_DMTOOLS_USERID")
Client = DMToolsClient(MY_DMTOOLS_USERID, MY_DMTOOLS_APIKEY)

# %%
import pandas as pd

# %%
df = pd.read_csv('list_columns.csv')
df.head(5)
# Out:
#       purpose   subject          key  value
# 0  list_table     graph      subject      0
# 1  list_table     graph   created_at      0
# 2  list_table     graph   updated_at      0
# 3  list_table     graph  archived_at      0
# 4  list_table  dropdown       old_id      0

# %%
for index, row in df.iterrows():
    purpose = row['purpose']
    subject = row['subject']
    key = row['key']
    value = row['value']
    data = { 'key_purpose' : purpose,
            'key_subject' : subject,
            'key' : key,
            'value' : str(value),
            'value_datatype' : 'integer'}
    print(data)
    r = Client.create(subject='graph', data=data)
            

#r = Client.read(subject='graph')
#r
# Out:
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'old_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'name', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'limit_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'nomhash', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'x_units', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'y_units', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'x_rescale', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'y_rescale', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'default_color', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'default_style', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'data_values', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'data', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'data_label', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'data_comment', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'data_reference', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'file_name', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'creator_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'date_of_run_start', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'date_of_run_end', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'date_of_announcement', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'date_official', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'rating', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'public', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'open', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'official', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'greatest_hit', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'old_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'old_plot_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'limit_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'open', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'old_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'old_name', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'old_user_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'x_min', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'x_max', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'y_min', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'y_max', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'x_units', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'y_units', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'user_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'plot_png', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'legend_png', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'plot_eps', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'legend_eps', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'no_id', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'open', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'subject', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'created_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'updated_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'archived_at', 'value': '0', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'open', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'parent_id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'key', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'value', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'graph', 'key': 'value_datatype', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'dropdown_subject', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'dropdown_display', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'dropdown_value', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'dropdown', 'key': 'open', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'plot_id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'color', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'limit_display', 'key': 'style', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'experiment', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'spin_dependency', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'result_type', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'measurement_type', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data', 'key': 'year', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'name', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'plot_id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'color', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'style', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'data_display', 'key': 'data_id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'plot', 'key': 'name', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'user_id', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'class_name', 'value': '1', 'value_datatype': 'integer'}
# {'key_purpose': 'list_table', 'key_subject': 'ownership', 'key': 'class_id', 'value': '1', 'value_datatype': 'integer'}

# %%
new_graph = {'parent_id': -1,
  'open': 0,
  'value': 'experiment',
  'created_at': '2024-08-27T15:27:27',
  'archived_at': '1980-01-01T00:00:00',
  'key': 'experiment',
  'subject': 'graph',
  'value_datatype': 'text',
  'updated_at': '2024-08-27T15:27:27'}

# %%
r = Client.create(subject='graph',data=new_graph)

# %%
r = Client.read(subject='graph')
r
# Out:
# [{'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:08',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 114,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:08'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:09',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 115,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:09'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:09',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 116,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:09'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:09',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 117,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:09'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:10',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 118,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'old_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:10'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:10',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 119,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:10'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:11',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 120,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:11'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:11',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 121,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:11'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:11',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 122,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:11'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:12',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 123,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:12'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:12',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 124,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:12'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:13',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 125,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:13'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:13',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 126,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:13'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:13',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 127,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'limit_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:13'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:14',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 128,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'nomhash',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:14'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:14',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 129,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'x_units',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:14'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:15',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 130,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'y_units',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:15'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:15',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 131,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'x_rescale',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:15'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:15',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 132,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'y_rescale',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:15'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:16',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 133,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'default_color',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:16'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:16',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 134,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'default_style',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:16'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:17',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 135,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'data_values',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:17'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:17',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 136,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'data',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:17'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:17',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 137,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'data_label',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:17'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:18',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 138,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'data_comment',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:18'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:18',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 139,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'data_reference',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:18'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:19',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 140,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'file_name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:19'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:19',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 141,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'creator_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:19'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:19',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 142,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'date_of_run_start',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:19'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:20',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 143,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'date_of_run_end',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:20'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:20',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 144,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'date_of_announcement',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:20'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:21',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 145,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'date_official',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:21'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:21',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 146,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'rating',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:21'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:21',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 147,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'public',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:21'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:22',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 148,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'open',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:22'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:22',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 149,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'official',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:22'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:23',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 150,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'greatest_hit',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:23'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:23',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 151,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:23'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:23',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 152,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:23'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:24',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 153,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:24'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:24',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 154,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:24'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:25',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 155,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'old_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:25'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:25',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 156,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'old_plot_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:25'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:25',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 157,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'limit_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:25'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:26',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 158,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:26'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:26',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 159,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:26'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:27',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 160,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:27'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:27',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 161,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'open',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:27'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:27',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 162,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:27'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:28',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 163,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'old_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:28'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:28',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 164,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'old_name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:28'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:29',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 165,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'old_user_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:29'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:29',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 166,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'x_min',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:29'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:29',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 167,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'x_max',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:29'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:30',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 168,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'y_min',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:30'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:30',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 169,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'y_max',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:30'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:31',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 170,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'x_units',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:31'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:31',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 171,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'y_units',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:31'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:31',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 172,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'user_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:31'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:32',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 173,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:32'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:32',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 174,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:32'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:33',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 175,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:33'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:33',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 176,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'plot_png',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:33'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:33',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 177,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'legend_png',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:33'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:34',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 178,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'plot_eps',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:34'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:34',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 179,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'legend_eps',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:34'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:35',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 180,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'no_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:35'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:35',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 181,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'open',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:35'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:36',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 182,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:36'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:36',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 183,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'created_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:36'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:36',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 184,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'updated_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:36'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '0',
#   'created_at': '2024-08-28T14:57:37',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 185,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'archived_at',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:37'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:37',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 186,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:37'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:38',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 187,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'open',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:38'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:38',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 188,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'parent_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:38'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:38',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 189,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'key',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:38'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:39',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 190,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'value',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:39'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:39',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 191,
#   'parent_id': -1,
#   'key_subject': 'graph',
#   'key': 'value_datatype',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:39'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:40',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 192,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:40'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:40',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 193,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'dropdown_subject',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:40'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:40',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 194,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'dropdown_display',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:40'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:41',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 195,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'dropdown_value',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:41'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:41',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 196,
#   'parent_id': -1,
#   'key_subject': 'dropdown',
#   'key': 'open',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:41'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:42',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 197,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:42'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:42',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 198,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'plot_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:42'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:42',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 199,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'color',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:42'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:43',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 200,
#   'parent_id': -1,
#   'key_subject': 'limit_display',
#   'key': 'style',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:43'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:43',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 201,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:43'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:44',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 202,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'experiment',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:44'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:44',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 203,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'spin_dependency',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:44'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:44',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 204,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'result_type',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:44'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:45',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 205,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'measurement_type',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:45'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:45',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 206,
#   'parent_id': -1,
#   'key_subject': 'data',
#   'key': 'year',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:45'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:46',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 207,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:46'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:46',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 208,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:46'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:46',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 209,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'plot_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:46'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:47',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 210,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'color',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:47'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:47',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 211,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'style',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:47'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:48',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 212,
#   'parent_id': -1,
#   'key_subject': 'data_display',
#   'key': 'data_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:48'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:48',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 213,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:48'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:48',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 214,
#   'parent_id': -1,
#   'key_subject': 'plot',
#   'key': 'name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:48'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:49',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 215,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:49'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:49',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 216,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'user_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:49'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:50',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 217,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'class_name',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:50'},
#  {'open': 1,
#   'key_purpose': 'list_table',
#   'value': '1',
#   'created_at': '2024-08-28T14:57:50',
#   'archived_at': '1980-01-01T00:00:00',
#   'subject': 'graph',
#   'id': 218,
#   'parent_id': -1,
#   'key_subject': 'ownership',
#   'key': 'class_id',
#   'value_datatype': 'integer',
#   'updated_at': '2024-08-28T14:57:50'}]
